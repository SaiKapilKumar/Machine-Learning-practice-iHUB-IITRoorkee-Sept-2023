# %% [markdown]
# # Seaborn
#
# statistical plotting library built on top of matplotlib

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# # Distribution plot
#
# shows distribution of a univariate(one variable) set of observations.

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
sns.distplot(df['total_bill'],kde = True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# kde: kernel density estimation calculates the density of features in the neighbourhood around those features.

# %%
sns.distplot(df['total_bill'],kde = True, bins = 30)



#bins defines smoothness or sharpness in your plot
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # jointplot
#
# match up two distplots for bivariate data. kind parameter: 'scatter', 'reg', 'kde', 'hex', 'resid'

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind= 'reg')
plt.show()

# %%
df[df['total_bill']>46]
# Out:
#      total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 59        48.27   6.73  Male     No  Sat  Dinner     4             12.07
# 156       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No  Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 59       Brian Ortiz  6596453823950595    Sat8139
# 156    Ryan Gonzales  3523151482063321    Sun7518
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind= 'kde')
plt.show()

# %% [markdown]
# # Pair-plot

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
sns.pairplot(df[['total_bill', 'tip','size','price_per_person']])
plt.show()

# %%
sns.pairplot(df[['total_bill', 'tip','size','price_per_person']])

# %%
sns.pairplot(df, hue='sex', palette='Set1')

# %%
sns.pairplot(df, hue='day', palette='Set1')
plt.show()

# %% [markdown]
# # RUG plot

# %%
sns.kdeplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(df['tip'])
sns.rugplot(df['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# # Categorical Data Plots
#
# ### Bar plot and Count Plot

# %%
sns.barplot(x='day',y='tip',data=df, hue = 'sex', estimator=np.mean)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(x='day',y='tip',data=df, hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.countplot(data=df, x='smoker')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %% [markdown]
# # Boxplot and Violinplot

# %%
sns.violinplot(y='smoker',x='total_bill',data = df, orient = 'h')
# Out:
# <Axes: xlabel='total_bill', ylabel='smoker'>
